# %%
from ingest_data import read_file , DataIngestorFactory
df = read_file(factory=DataIngestorFactory,file_extensiton='.zip', file_path="../data/folder.zip", file_name="AmedsHousing.csv")
# Out:
# Number of CSV files = 2
# ['AmesHousing.csv', 'house.csv']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 from ingest_data import read_file , DataIngestorFactory
# ----> 2 df = read_file(factory=DataIngestorFactory,file_extensiton='.zip', file_path="../data/folder.zip", file_name="AmedsHousing.csv")
#
# File c:\Users\hp\Files\DataScience\End-To-End Projects\House Price Prediction\src\ingest_data.py:74, in read_file(factory, file_extensiton, file_path, file_name)
#      72 def read_file(factory:DataIngestorFactory, file_extensiton, file_path, file_name=None):
#      73     ingestor = factory.get_data_ingestor(file_extensiton)
# ---> 74     return ingestor.ingest(file_path, file_name=file_name)
#
# ...

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...
